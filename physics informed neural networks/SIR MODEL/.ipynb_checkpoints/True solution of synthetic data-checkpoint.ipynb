# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# Total population, N.
N = 762
# Initial number of infected and recovered individuals, I0 and R0.
I0, R0 = 1, 0
# Everyone else, S0, is susceptible to infection initially.
S0 = N - I0 - R0
# Contact rate, beta, and mean recovery rate, gamma, (in 1/days).
beta, gamma = 0.0026, 0.5 
# A grid of time points (in days)
t = np.linspace(0, 20, 20)

# The SIR model differential equations.
def deriv(y, t, N, beta, gamma):
    S, I, R = y
    dSdt = -beta * S * I 
    dIdt = beta * S * I  - gamma * I
    dRdt = gamma * I
    return dSdt, dIdt, dRdt

# Initial conditions vector
y0 = S0, I0, R0
# Integrate the SIR equations over the time grid, t.
ret = odeint(deriv, y0, t, args=(N, beta, gamma))
S, I, R = ret.T

# Plot the data on three separate curves for S(t), I(t) and R(t)
plt.figure()
plt.plot(t,S,color='blue',label = 'susceptible')
plt.plot(t,I,color='red',label = 'infected')
plt.plot(t,R,color='yellow',label = 'recovered')
plt.legend()
plt.savefig('SIRmodel_truesolution.pdf')
plt.show()

# %%
import pandas as pd
import csv

# %%
data = {
    'Susceptible' : S,
    'Infected' : I,
    'Recovered' : R,
}
df = pd.DataFrame(data)

# %%
df
# Out:
#     Susceptible    Infected   Recovered
# 0    761.000000    1.000000    0.000000
# 1    756.019770    4.717570    1.262660
# 2    733.324285   21.551610    7.124105
# 3    643.950599   85.931836   32.117565
# 4    424.813976  225.074101  112.111922
# 5    198.985551  305.052688  257.961761
# 6     90.032211  261.493592  410.474197
# 7     48.876470  185.174058  527.949472
# 8     32.253102  121.858603  607.888294
# 9     24.644398   77.724113  659.631488
# 10    20.785684   48.835685  692.378631
# 11    18.684625   30.443767  712.871608
# 12    17.486302   18.895328  725.618370
# 13    16.782404   11.697905  733.519692
# 14    16.361217    7.231163  738.407620
# 15    16.106275    4.465961  741.427763
# 16    15.950855    2.756658  743.292488
# 17    15.855685    1.701002  744.443313
# 18    15.797250    1.049391  745.153359
# 19    15.761310    0.647313  745.591377

# %%
df.to_csv("true_solution.csv")

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# Total population, N.
N = 762
# Initial number of infected and recovered individuals, I0 and R0.
I0, R0 = 1, 0
# Everyone else, S0, is susceptible to infection initially.
S0 = N - I0 - R0
# Contact rate, beta, and mean recovery rate, gamma, (in 1/days).
beta, gamma = 0.002,0.515
# A grid of time points (in days)
t = np.linspace(0, 20, 20)

# The SIR model differential equations.
def deriv(y, t, N, beta, gamma):
    S, I, R, = y
    dSdt = -beta * S * I 
    dIdt = beta * S * I  - gamma * I
    dRdt = gamma * I
    return dSdt, dIdt, dRdt

# Initial conditions vector
y0 = S0, I0, R0
# Integrate the SIR equations over the time grid, t.
ret = odeint(deriv, y0, t, args=(N, beta, gamma))
S, I, R = ret.T

# Plot the data on three separate curves for S(t), I(t) and R(t)
plt.figure()
plt.plot(t,S,color='blue',label = 'susceptible')
plt.plot(t,I,color='red',label = 'infected')
plt.plot(t,R,color='yellow',label = 'recovered')
plt.legend()
plt.show()
